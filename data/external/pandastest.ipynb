# %%
import pandas as pd

# %%
df = pd.read_csv(r'steam_api.csv') 
df.head(50)
# Out:
#                      APIname                            sub_APIname  version  \
# 0         IGCVersion_1046930                       GetClientVersion        1
# 1         IGCVersion_1046930                       GetServerVersion        1
# 2         IGCVersion_1269260                       GetClientVersion        1
# 3         IGCVersion_1269260                       GetServerVersion        1
# 4             IGCVersion_440                       GetClientVersion        1
# 5             IGCVersion_440                       GetServerVersion        1
# 6             IGCVersion_570                       GetClientVersion        1
# 7             IGCVersion_570                       GetServerVersion        1
# 8          IGCVersion_583950                       GetClientVersion        1
# 9          IGCVersion_583950                       GetServerVersion        1
# 10            IGCVersion_730                       GetServerVersion        1
# ...

# %%
df.loc[df['sub_APIname'] =='GetPlayerSummaries']
# Out:
#        APIname         sub_APIname  version httpmethod  \
# 28  ISteamUser  GetPlayerSummaries        1        GET
# 29  ISteamUser  GetPlayerSummaries        2        GET
#
#                                            parameters
# 28  [\r\n                            {\r\n        ...
# 29  [\r\n                            {\r\n        ...
